# %% [markdown]
# ### Data dictionary:
#
# Index: Row index
#
# user id: User ID (unique)
#
# test group: If "ad" the person saw the advertisement, if "psa" they only saw the public service announcement
#
# converted: If a person bought the product then True, else is False
#
# total ads: Amount of ads seen by person
#
# most ads day: Day that the person saw the biggest amount of ads
#
# most ads hour: Hour of day that the person saw the biggest amount of ads

# %%
import pandas as pd 

df = (pd.read_csv('marketing_AB.csv')).drop('Unnamed: 0', axis=1)
df.converted = df.converted.astype(int)
df
# Out:
#         user id test group  converted  total ads most ads day  most ads hour
# 0       1069124         ad          0        130       Monday             20
# 1       1119715         ad          0         93      Tuesday             22
# 2       1144181         ad          0         21      Tuesday             18
# 3       1435133         ad          0        355      Tuesday             10
# 4       1015700         ad          0        276       Friday             14
# ...         ...        ...        ...        ...          ...            ...
# 588096  1278437         ad          0          1      Tuesday             23
# 588097  1327975         ad          0          1      Tuesday             23
# 588098  1038442         ad          0          3      Tuesday             23
# 588099  1496395         ad          0          1      Tuesday             23
# 588100  1237779         ad          0          1      Tuesday             23
#
# [588101 rows x 6 columns]

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_ffa81 thead>tr>th {
#   text-align: left;
# }
# #T_ffa81_row0_col0, #T_ffa81_row1_col0, #T_ffa81_row2_col0, #T_ffa81_row3_col0, #T_ffa81_row4_col0, #T_ffa81_row5_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_ffa81_row0_col1, #T_ffa81_row1_col1, #T_ffa81_row2_col1, #T_ffa81_row3_col1, #T_ffa81_row4_col1, #T_ffa81_row5_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_ffa81_row0_col2, #T_ffa81_row1_col2, #T_ffa81_row2_col2, #T_ffa81_row3_col2, #T_ffa81_row4_col2, #T_ffa81_row5_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_ffa81_row0_col3, #T_ffa81_row1_col3, #T_ffa81_row2_col3, #T_ffa81_row3_col3, #T_ffa81_row4_col3, #T_ffa81_row5_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_ffa81_row0_col4, #T_ffa81_row1_col4, #T_ffa81_row2_col4, #T_ffa81_row3_col4, #T_ffa81_row4_col4, #T_ffa81_row5_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_ffa81_row0_col5, #T_ffa81_row1_col5, #T_ffa81_row2_col5, #T_ffa81_row3_col5, #T_ffa81_row4_col5, #T_ffa81_row5_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_ffa81">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 588,101 x 6<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_ffa81_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_ffa81_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_ffa81_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_ffa81_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_ffa81_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_ffa81_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ffa81_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ffa81_row0_col1" class="data row0 col1" ><strong>user id</strong><br>[int64]</td>
#       <td id="T_ffa81_row0_col2" class="data row0 col2" >Mean (sd) : 1310692.2 (202226.0)<br>min < med < max:<br>900000.0 < 1313725.0 < 1654483.0<br>IQR (CV) : 340898.0 (6.5)</td>
#       <td id="T_ffa81_row0_col3" class="data row0 col3" >588,101 distinct values</td>
#       <td id="T_ffa81_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ffa81_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ffa81_row1_col1" class="data row1 col1" ><strong>test group</strong><br>[object]</td>
#       <td id="T_ffa81_row1_col2" class="data row1 col2" >1. ad<br>2. psa</td>
#       <td id="T_ffa81_row1_col3" class="data row1 col3" >564,577 (96.0%)<br>23,524 (4.0%)</td>
#       <td id="T_ffa81_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ffa81_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ffa81_row2_col1" class="data row2 col1" ><strong>converted</strong><br>[int64]</td>
#       <td id="T_ffa81_row2_col2" class="data row2 col2" >1. 0<br>2. 1</td>
#       <td id="T_ffa81_row2_col3" class="data row2 col3" >573,258 (97.5%)<br>14,843 (2.5%)</td>
#       <td id="T_ffa81_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ffa81_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ffa81_row3_col1" class="data row3 col1" ><strong>total ads</strong><br>[int64]</td>
#       <td id="T_ffa81_row3_col2" class="data row3 col2" >Mean (sd) : 24.8 (43.7)<br>min < med < max:<br>1.0 < 13.0 < 2065.0<br>IQR (CV) : 23.0 (0.6)</td>
#       <td id="T_ffa81_row3_col3" class="data row3 col3" >807 distinct values</td>
#       <td id="T_ffa81_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ffa81_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ffa81_row4_col1" class="data row4 col1" ><strong>most ads day</strong><br>[object]</td>
#       <td id="T_ffa81_row4_col2" class="data row4 col2" >1. Friday<br>2. Monday<br>3. Sunday<br>4. Thursday<br>5. Saturday<br>6. Wednesday<br>7. Tuesday</td>
#       <td id="T_ffa81_row4_col3" class="data row4 col3" >92,608 (15.7%)<br>87,073 (14.8%)<br>85,391 (14.5%)<br>82,982 (14.1%)<br>81,660 (13.9%)<br>80,908 (13.8%)<br>77,479 (13.2%)</td>
#       <td id="T_ffa81_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ffa81_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ffa81_row5_col1" class="data row5 col1" ><strong>most ads hour</strong><br>[int64]</td>
#       <td id="T_ffa81_row5_col2" class="data row5 col2" >Mean (sd) : 14.5 (4.8)<br>min < med < max:<br>0.0 < 14.0 < 23.0<br>IQR (CV) : 7.0 (3.0)</td>
#       <td id="T_ffa81_row5_col3" class="data row5 col3" >24 distinct values</td>
#       <td id="T_ffa81_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_ffa81_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
treatment_count = df[df['test group'] == 'ad'].shape[0]
control_count = df[df['test group'] == 'psa'].shape[0]

print(f"Number of treatment IDs: {treatment_count}")
print(f"Number of control IDs: {control_count}")
# Out:
# Number of treatment IDs: 564577
# Number of control IDs: 23524

# %% [markdown]
# Making balanced groups and grouping the data by test group

# %%
treatment_group = df[df['test group'] == 'ad']
control_group = df[df['test group'] == 'psa']

treatment_group = treatment_group.sample(23524)

print(treatment_group.info())
print('')
print(control_group.info())

balanced_df = pd.concat([treatment_group, control_group], axis=0)
#balanced_df = balanced_df.groupby('test group')['converted'].mean()
balanced_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23524 entries, 186287 to 201987
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user id        23524 non-null  int64
#  1   test group     23524 non-null  object
#  2   converted      23524 non-null  int64
#  3   total ads      23524 non-null  int64
#  4   most ads day   23524 non-null  object
#  5   most ads hour  23524 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.3+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 23524 entries, 18 to 588081
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user id        23524 non-null  int64
#  1   test group     23524 non-null  object
#  2   converted      23524 non-null  int64
#  3   total ads      23524 non-null  int64
#  4   most ads day   23524 non-null  object
#  5   most ads hour  23524 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.3+ MB
# None
#         user id test group  converted  total ads most ads day  most ads hour
# 186287  1380967         ad          0         33       Monday              0
# 274517  1631043         ad          0         14    Wednesday             11
# 71801   1558982         ad          0         23     Saturday             14
# 42948   1465873         ad          0         94       Sunday             16
# 435376  1188726         ad          0          1     Saturday             13
# ...         ...        ...        ...        ...          ...            ...
# 588052   900959        psa          0         16      Tuesday             22
# 588063   902828        psa          0          3      Tuesday             22
# 588066   914578        psa          0          1      Tuesday             22
# 588069   909042        psa          0          6      Tuesday             22
# 588081   904721        psa          0         16      Tuesday             23
#
# [47048 rows x 6 columns]

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(balanced_df['test group'], balanced_df['converted'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-square: {chi2}, P-value: {p}")
# Out:
# Chi-square: 37.880253824674476, P-value: 7.522276275604638e-10

# %%
balanced_df
# Out:
#         user id test group  converted  total ads most ads day  most ads hour
# 186287  1380967         ad          0         33       Monday              0
# 274517  1631043         ad          0         14    Wednesday             11
# 71801   1558982         ad          0         23     Saturday             14
# 42948   1465873         ad          0         94       Sunday             16
# 435376  1188726         ad          0          1     Saturday             13
# ...         ...        ...        ...        ...          ...            ...
# 588052   900959        psa          0         16      Tuesday             22
# 588063   902828        psa          0          3      Tuesday             22
# 588066   914578        psa          0          1      Tuesday             22
# 588069   909042        psa          0          6      Tuesday             22
# 588081   904721        psa          0         16      Tuesday             23
#
# [47048 rows x 6 columns]
